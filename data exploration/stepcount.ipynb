# %%
import os

directory_list = []
for root, dirs, files in os.walk("/Users/ibergeland/Downloads/step_counts/", topdown=False):
    for name in dirs:
        directory_list.append(os.path.join(root, name))

import glob
import pandas as pd

step_count=pd.DataFrame()
filenames=pd.DataFrame()
str='/*.xls'
paths=[x+str for x in directory_list]
paths.sort()

# %%
for path in paths:
    filenames = glob.glob(path)
    for filename in filenames:
        df=pd.read_excel(filename, sheet_name='Activities')
        df['studyID']=path[46:50]
        step_count=step_count.append(df)
step_count=step_count.set_index('studyID')
step_count
# Out:
#                Date Calories Burned   Steps  Distance  Floors  \
# studyID
# 2001     2015-07-23           2,902   9,865      4.55     0.0
# 2001     2015-07-24           2,637   6,695      3.12     0.0
# 2001     2015-07-25           2,508   5,311      2.44     0.0
# 2001     2015-07-26           2,222   2,176      1.00     0.0
# 2001     2015-07-27           3,491  16,141     10.72     0.0
# 2001     2015-07-28           3,654  17,842     12.25     0.0
# 2001     2015-07-29           2,472   4,471      2.07     0.0
# 2001     2015-07-30           2,373   3,482      1.63     0.0
# 2001     2015-07-31           4,127  23,967     11.01     0.0
# 2001     2015-08-01           2,096   1,224      0.56     0.0
# 2001     2015-08-02           2,489   4,832      2.31     0.0
# 2001     2015-08-03           1,994       0      0.00     0.0
# 2001     2015-08-04           2,263   2,713      1.25     0.0
# 2001     2015-08-05           2,981  16,479      9.11     0.0
# ...
